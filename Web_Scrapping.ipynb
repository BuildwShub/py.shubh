# %% [markdown]
# <a href="https://colab.research.google.com/github/BuildwShub/py.shubh/blob/main/Web_Scrapping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

books_info = []

website = "https://books.toscrape.com/"
r = requests.get(website)

soup = BeautifulSoup(r.content, "html.parser")
book = soup.find_all("li", class_="col-xs-6 col-sm-4 col-md-3 col-lg-3")

for item in book:
    name_tag = item.find("h3").find("a")
    book_name = name_tag.text.strip()
    book_link = "https://books.toscrape.com/" + name_tag["href"]
    price = item.find("p", class_="price_color").text.strip()

    all_products = {
        "Name": book_name,
        "Price": price,
        "Link": book_link
    }

    books_info.append(all_products)

df = pd.DataFrame(books_info)
df.to_excel("Book_Info.xlsx", index=False)

print("Excel file created successfully")
# Out:
# Excel file created successfully
